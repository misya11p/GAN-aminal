# %%
import requests
from bs4 import BeautifulSoup
import sys

# query = sys.argv[1]

# %%
query = 'インコ'

# %%
url = f'https://www.google.com/search?q={query}&tbm=isch'
src = BeautifulSoup(requests.get(url).content, 'html.parser')

# %%
images = src.find_all('img')

# %%
images
# Out:
# [<img alt="Google" class="kgJEQe" src="/images/branding/searchlogo/1x/googlelogo_desk_heirloom_color_150x55dp.gif"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQClZxUy3tF2sjaBQ_-ZGHJzbJQUrFwHEwGTzIN8Iv8PyGmJKqcnfkGI4QA5A&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT0JB0Vsk2gTrC6LXGVzAGlJWDJ3iTUR6RjVMGic5Q9LqUuHoPosr7kPeV43A&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTsw13YrbmzOjLuqN0qzaNv32YRskSA2-8979ftwRNYkC2H7DBGzp85icmkVQ&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSgC1dIh3k7fbBkMciTKQ3BlKyiQmW8-YqMosmirzjAGmLa2mZJHiWe9KoG7g&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS2Zpb4nELKlTI72fGwbhwS1PBVt07LN1HIFRKU_VHSNbO6dA81W-Jjd1UikQ&amp;s"/>,
# ...
